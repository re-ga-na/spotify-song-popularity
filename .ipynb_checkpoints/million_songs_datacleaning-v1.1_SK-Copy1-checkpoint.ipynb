# %%
import pandas as pd
import requests
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv("subset_unique_tracks.txt",delimiter='<SEP>')
df.to_csv('Demo1.csv')
df = df.drop(columns=['Id', 'id2'])
df.columns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# Index(['ArtistName', 'SongTitle'], dtype='object')

# %%
df.head()
# Out:
#          ArtistName         SongTitle
# 0            Casual  I Didn't Mean To
# 1      The Box Tops         Soul Deep
# 2  Sonora Santanera   Amor De Cabaret
# 3          Adam Ant   Something Girls
# 4               Gob    Face the Ashes

# %%
#setting up link to spotify api w spotipy
client_id = "5028c957611248149d8c04007258f254"
client_secret = "aa56a507cb944f488f8835062a94115c"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#next steps = make a loop to iterate through each row of the dataframe
#save each song's id, audio features, and popularity score in a column
#if desired, we can make the dataset bigger

# %%
#test dataframe
dft = df.head(20)
dft
# Out:
#                ArtistName                                    SongTitle
# 0                  Casual                             I Didn't Mean To
# 1            The Box Tops                                    Soul Deep
# 2        Sonora Santanera                              Amor De Cabaret
# 3                Adam Ant                              Something Girls
# 4                     Gob                               Face the Ashes
# 5   Jeff And Sheri Easter  The Moon And I (Ordinary Day Album Version)
# 6                 Rated R                        Keepin It Real (Skit)
# 7   Tweeterfriendly Music                                 Drop of Rain
# 8        Planet P Project                                   Pink World
# 9                     Clp            Insatiable (Instrumental Version)
# 10           JennyAnyKind                              Young Boy Blues
# 11           Wayne Watson                     The Urgency (LP Version)
# 12              Andy Andy                                     La Culpa
# 13              Bob Azzam                               Auguri Cha Cha
# 14          Lionel Richie                      Tonight Will Be Alright
# 15             Blue Rodeo                                     Floating
# 16        Richard Souther                                    High Tide
# 17          Faiz Ali Faiz                         Sohna Nee Sohna Data
# 18                  Tesla                            Caught In A Dream
# 19              lextrical                              Synthetic Dream

# %%
artistname="casual"
search_str = "I Didn't Mean To"
result= sp.search(search_str+":"+artistname,type="track,artist")
idt = result["tracks"]["items"][0]["id"]
ft1 = sp.audio_features(idt)
ft2 = pd.DataFrame(ft1)
ft2["popularity"] = sp.track(idt)["popularity"]
ft2["Artist"] = artistname
ft2["Track"] = search_str
ft2
# Out:
#    acousticness                                       analysis_url  \
# 0         0.063  https://api.spotify.com/v1/audio-analysis/01TR...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.751       218933   0.549  01TR6aAKrA2cI3Z0gnCOsu
#
#    instrumentalness  key  liveness  loudness  ...  speechiness   tempo  \
# 0          0.000025    6     0.106   -10.508  ...        0.429  92.224
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/01TR6aAKrA2c...
#
#              type                                   uri valence  popularity  \
# 0  audio_features  spotify:track:01TR6aAKrA2cI3Z0gnCOsu   0.553          21
#
#    Artist             Track
# 0  casual  I Didn't Mean To
#
# [1 rows x 21 columns]

# %%
pop = ft2["popularity"]
pop
# Out:
# 0    21
# Name: popularity, dtype: int64

# %%
# iterate over the dataframe row by row
for index_label, row in dft.iterrows():
   # For each row update the 'Bonus' value to it's double  

    try: 
        artistname= row['ArtistName']
        search_str =  row['SongTitle']
        print(artistname+ ","+ search_str )
        result= sp.search(search_str+":"+artistname,type="track,artist")
        print(result["tracks"]["items"][0]["id"])
        idr = result["tracks"]["items"][0]["id"]
        ftr2 = sp.audio_features(idr)
        ftr2 = pd.DataFrame(ftr2)
        ftr2["popularity"] = sp.track(idr)["popularity"]
        ftr2["Artist"] = artistname
        ftr2["Track"] = search_str
        ftr2 = ftr2.append(ftr2)
        
    except: 
        print ('data not found')
# Out:
# Casual,I Didn't Mean To
# 01TR6aAKrA2cI3Z0gnCOsu
# The Box Tops,Soul Deep
# 4yPl1mK1oluIrCwI4HInPR
# Sonora Santanera,Amor De Cabaret
# 5JeyXbf7CrVQ8DqwFikN0P
# Adam Ant,Something Girls
# 0ygZMtr5JdKEk1Nn58HB0V
# Gob,Face the Ashes
# 4cdbM6efK43Cs2PDMtzdhv
# Jeff And Sheri Easter,The Moon And I (Ordinary Day Album Version)
# 7ERvcsBBYzSHqQQqlI9xAN
# Rated R,Keepin It Real (Skit)
# 0e4hF4Jxyh7cuwB2pMYhBh
# Tweeterfriendly Music,Drop of Rain
# 6dfppQDZQ4x3fCs6N89kV3
# Planet P Project,Pink World
# 0CVy6Avr53ZCYfHSDGVftj
# Clp,Insatiable (Instrumental Version)
# data not found
# JennyAnyKind,Young Boy Blues
# 5uN6oY2NGLC6GKoywHKkZA
# Wayne Watson,The Urgency (LP Version)
# data not found
# Andy Andy,La Culpa
# 4NPrFFGPfS4el9lbtC5gGZ
# Bob Azzam,Auguri Cha Cha
# 76AhmOfTWXbCVXkZaDfRY5
# Lionel Richie,Tonight Will Be Alright
# 2Jr12fpsMdIM6weoUDMf9u
# Blue Rodeo,Floating
# 3eS7eHlOBosVccCVHmEj6W
# Richard Souther,High Tide
# 05N0fj2Alt0efIZ7XZ2m6J
# Faiz Ali Faiz,Sohna Nee Sohna Data
# 3ukWqBHE8jIlRSKNP99I7X
# Tesla,Caught In A Dream
# 4iNtHYpGuqu0iz18QVFhAo
# lextrical,Synthetic Dream
# 01rXKwe1sC4OJvI01BmhAL

# %%
ftr2
# Out:
#    acousticness                                       analysis_url  \
# 0         0.621  https://api.spotify.com/v1/audio-analysis/01rX...
# 0         0.621  https://api.spotify.com/v1/audio-analysis/01rX...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.583       168080   0.589  01rXKwe1sC4OJvI01BmhAL
# 0         0.583       168080   0.589  01rXKwe1sC4OJvI01BmhAL
#
#    instrumentalness  key  liveness  loudness  ...  speechiness    tempo  \
# 0              0.89    0     0.139    -6.856  ...       0.0298  138.339
# 0              0.89    0     0.139    -6.856  ...       0.0298  138.339
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/01rXKwe1sC4O...
# 0               4  https://api.spotify.com/v1/tracks/01rXKwe1sC4O...
#
#              type                                   uri valence  popularity  \
# 0  audio_features  spotify:track:01rXKwe1sC4OJvI01BmhAL   0.277           0
# 0  audio_features  spotify:track:01rXKwe1sC4OJvI01BmhAL   0.277           0
#
#       Artist            Track
# 0  lextrical  Synthetic Dream
# 0  lextrical  Synthetic Dream
#
# [2 rows x 21 columns]

# %%
ft2.columns
# Out:
# Index(['acousticness', 'analysis_url', 'danceability', 'duration_ms', 'energy',
#        'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'track_href', 'type', 'uri',
#        'valence', 'popularity', 'Artist', 'Track'],
#       dtype='object')

# %%
ft2 = ft2.drop(columns=['analysis_url', 'id', 'track_href', 'type', 'uri'])

# %%
ft2
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0         0.063         0.751       218933   0.549          0.000025    6
#
#    liveness  loudness  mode  speechiness   tempo  time_signature  valence  \
# 0     0.106   -10.508     0        0.429  92.224               4    0.553
#
#    popularity  Artist             Track
# 0          21  casual  I Didn't Mean To

# %%
pop = ft2["popularity"].astype(int)
pop
# Out:
# 0    21
# Name: popularity, dtype: int32

# %%
# iterate over the dataframe row by row
for index_label, row in dft.iterrows():
   # For each row update the 'Bonus' value to it's double  

    try: 
        artistname= row['ArtistName']
        search_str =  row['SongTitle']
        print(artistname+ ","+ search_str )
        result= sp.search(search_str+":"+artistname,type="track,artist")
        print(result["tracks"]["items"][0]["id"])
        idr = result["tracks"]["items"][0]["id"]
        ftr = sp.audio_features(idr)
        ftr2 = pd.DataFrame(ftr)
        ftr2["popularity"] = sp.track(idr)["popularity"]
        ftr2["Artist"] = artistname
        ftr2["Track"] = search_str
        ft2 = ft2.append(ftr2)
        
    except: 
        print ('data not found')
# Out:
# Casual,I Didn't Mean To
# 01TR6aAKrA2cI3Z0gnCOsu
# The Box Tops,Soul Deep
# 4yPl1mK1oluIrCwI4HInPR
# Sonora Santanera,Amor De Cabaret
# 5JeyXbf7CrVQ8DqwFikN0P
# Adam Ant,Something Girls
# 0ygZMtr5JdKEk1Nn58HB0V
# Gob,Face the Ashes
# 4cdbM6efK43Cs2PDMtzdhv
# Jeff And Sheri Easter,The Moon And I (Ordinary Day Album Version)
# 7ERvcsBBYzSHqQQqlI9xAN
# Rated R,Keepin It Real (Skit)
# 0e4hF4Jxyh7cuwB2pMYhBh
# Tweeterfriendly Music,Drop of Rain
# 6dfppQDZQ4x3fCs6N89kV3
# Planet P Project,Pink World
# 0CVy6Avr53ZCYfHSDGVftj
# Clp,Insatiable (Instrumental Version)
# data not found
# JennyAnyKind,Young Boy Blues
# 5uN6oY2NGLC6GKoywHKkZA
# Wayne Watson,The Urgency (LP Version)
# data not found
# Andy Andy,La Culpa
# 4NPrFFGPfS4el9lbtC5gGZ
# Bob Azzam,Auguri Cha Cha
# 76AhmOfTWXbCVXkZaDfRY5
# Lionel Richie,Tonight Will Be Alright
# 2Jr12fpsMdIM6weoUDMf9u
# Blue Rodeo,Floating
# 3eS7eHlOBosVccCVHmEj6W
# Richard Souther,High Tide
# 05N0fj2Alt0efIZ7XZ2m6J
# Faiz Ali Faiz,Sohna Nee Sohna Data
# 3ukWqBHE8jIlRSKNP99I7X
# Tesla,Caught In A Dream
# 4iNtHYpGuqu0iz18QVFhAo
# lextrical,Synthetic Dream
# 01rXKwe1sC4OJvI01BmhAL

# %%
ft2 = ft2.drop(columns=['analysis_url', 'id', 'track_href', 'type', 'uri'])

# %%
ft2
# Out:
#                   Artist                                        Track  \
# 0                 casual                             I Didn't Mean To
# 0                 Casual                             I Didn't Mean To
# 0           The Box Tops                                    Soul Deep
# 0       Sonora Santanera                              Amor De Cabaret
# 0               Adam Ant                              Something Girls
# 0                    Gob                               Face the Ashes
# 0  Jeff And Sheri Easter  The Moon And I (Ordinary Day Album Version)
# 0                Rated R                        Keepin It Real (Skit)
# 0      0.308000         0.569       599240   0.876          0.152000    6
# 0      0.000296         0.560       290333   0.678          0.003560    7
# 0      0.621000         0.583       168080   0.589          0.890000    0
#
#    liveness  loudness  mode  popularity  speechiness    tempo  time_signature  \
# 0    0.1060   -10.508     0        21.0       0.4290   92.224               4
# 0    0.1060   -10.508     0         NaN       0.4290   92.224               4
# 0    0.0748   -12.940     1         NaN       0.0326  121.395               4
# 0    0.9350    -6.422     1         NaN       0.0290  102.463               4
# 0    0.1630    -3.808     1         NaN       0.0443  120.135               4
# 0    0.0904    -4.512     1         NaN       0.0543  129.727               4
# 0    0.0833    -8.328     1         NaN       0.0325  147.565               4
# 0    0.2300   -16.056     1         NaN       0.8950   83.834               4
# 0    0.0963   -10.716     1         NaN       0.0352  100.315               3
# 0    0.4790    -5.312     0         NaN       0.0467  104.953               4
# 0    0.0988    -9.159     0         NaN       0.0495  146.609               4
# 0    0.0709    -7.128     0         NaN       0.1780  176.042               4
# 0    0.3670   -11.190     1         NaN       0.0332  137.377               4
# 0    0.0516    -8.213     1         NaN       0.0283  125.187               4
# 0    0.3440    -7.233     1         NaN       0.0267  118.243               4
# 0    0.0428   -16.578     1         NaN       0.0415   95.807               4
# 0    0.4720    -6.505     1         NaN       0.0426   99.325               4
# 0    0.0606    -5.141     1         NaN       0.0259  150.124               4
# 0    0.1390    -6.856     1         NaN       0.0298  138.339               4
# 0    0.1060   -10.508     0        21.0       0.4290   92.224               4
# 0    0.0748   -12.940     1        37.0       0.0326  121.395               4
# 0    0.9350    -6.422     1        50.0       0.0290  102.463               4
# 0    0.1630    -3.808     1        19.0       0.0443  120.135               4
# 0    0.0904    -4.512     1        10.0       0.0543  129.727               4
# 0    0.0833    -8.328     1         1.0       0.0325  147.565               4
# 0    0.2300   -16.056     1         0.0       0.8950   83.834               4
# 0    0.0963   -10.716     1         0.0       0.0352  100.315               3
# 0    0.4790    -5.312     0        12.0       0.0467  104.953               4
# 0    0.0988    -9.159     0         0.0       0.0495  146.609               4
# 0    0.0709    -7.128     0         1.0       0.1780  176.042               4
# 0    0.3670   -11.190     1         0.0       0.0332  137.377               4
# 0    0.0516    -8.213     1        37.0       0.0283  125.187               4
# 0    0.3440    -7.233     1        11.0       0.0267  118.243               4
# 0    0.0428   -16.578     1         3.0       0.0415   95.807               4
# 0    0.4720    -6.505     1         0.0       0.0426   99.325               4
# 0    0.0606    -5.141     1        29.0       0.0259  150.124               4
# 0    0.1390    -6.856     1         0.0       0.0298  138.339               4
#
#    valence
# 0    0.553
# 0    0.553
# 0    0.966
# 0    0.676
# 0    0.853
# 0    0.655
# 0    0.286
# 0    0.696
# 0    0.185
# 0    0.327
# 0    0.203
# 0    0.874
# 0    0.870
# 0    0.716
# 0    0.834
# 0    0.640
# 0    0.931
# 0    0.319
# 0    0.277
# 0    0.553
# 0    0.966
# 0    0.676
# 0    0.853
# 0    0.655
# 0    0.286
# 0    0.696
# 0    0.185
# 0    0.327
# 0    0.203
# 0    0.874
# 0    0.870
# 0    0.716
# 0    0.834
# 0    0.640
# 0    0.931
# 0    0.319
# 0    0.277
