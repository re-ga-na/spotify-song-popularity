# %%
import pandas as pd
import requests
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv("subset_unique_tracks.txt",delimiter='<SEP>')
df.to_csv('Demo1.csv')
df = df.drop(columns=['Id', 'id2'])
df.columns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# Index(['ArtistName', 'SongTitle'], dtype='object')

# %%
df.head()
# Out:
#          ArtistName         SongTitle
# 0            Casual  I Didn't Mean To
# 1      The Box Tops         Soul Deep
# 2  Sonora Santanera   Amor De Cabaret
# 3          Adam Ant   Something Girls
# 4               Gob    Face the Ashes

# %%
#setting up link to spotify api w spotipy
client_id = "5028c957611248149d8c04007258f254"
client_secret = "aa56a507cb944f488f8835062a94115c"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#next steps = make a loop to iterate through each row of the dataframe
#save each song's id, audio features, and popularity score in a column
#if desired, we can make the dataset bigger

# %%
#test dataframe
dft = df.head(20)
dft
# Out:
#                ArtistName                                    SongTitle
# 0                  Casual                             I Didn't Mean To
# 1            The Box Tops                                    Soul Deep
# 2        Sonora Santanera                              Amor De Cabaret
# 3                Adam Ant                              Something Girls
# 4                     Gob                               Face the Ashes
# 5   Jeff And Sheri Easter  The Moon And I (Ordinary Day Album Version)
# 6                 Rated R                        Keepin It Real (Skit)
# 7   Tweeterfriendly Music                                 Drop of Rain
# 8        Planet P Project                                   Pink World
# 9                     Clp            Insatiable (Instrumental Version)
# 10           JennyAnyKind                              Young Boy Blues
# 11           Wayne Watson                     The Urgency (LP Version)
# 12              Andy Andy                                     La Culpa
# 13              Bob Azzam                               Auguri Cha Cha
# 14          Lionel Richie                      Tonight Will Be Alright
# 15             Blue Rodeo                                     Floating
# 16        Richard Souther                                    High Tide
# 17          Faiz Ali Faiz                         Sohna Nee Sohna Data
# 18                  Tesla                            Caught In A Dream
# 19              lextrical                              Synthetic Dream

# %%
artistname="casual"
search_str = "I Didn't Mean To"
result= sp.search(search_str+":"+artistname,type="track,artist")
idt = result["tracks"]["items"][0]["id"]
ft1 = sp.audio_features(idt)
ft2 = pd.DataFrame(ft1)
ft2["popularity"] = sp.track(idt)["popularity"]
ft2["Artist"] = artistname
ft2["Track"] = search_str
ft2
# Out:
#    acousticness                                       analysis_url  \
# 0         0.063  https://api.spotify.com/v1/audio-analysis/01TR...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.751       218933   0.549  01TR6aAKrA2cI3Z0gnCOsu
#
#    instrumentalness  key  liveness  loudness  ...  speechiness   tempo  \
# 0          0.000025    6     0.106   -10.508  ...        0.429  92.224
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/01TR6aAKrA2c...
#
#              type                                   uri valence  popularity  \
# 0  audio_features  spotify:track:01TR6aAKrA2cI3Z0gnCOsu   0.553          21
#
#    Artist             Track
# 0  casual  I Didn't Mean To
#
# [1 rows x 21 columns]

# %%
# iterate over the dataframe row by row
for index_label, row in dft.iterrows():
   # For each row update the 'Bonus' value to it's double  
    artistname= row['ArtistName']
    search_str =  row['SongTitle']
    print(artistname+ ","+ search_str )
    result= sp.search(search_str+":"+artistname,type="track,artist")
    print(result["tracks"]["items"][0]["id"])
    idr = result["tracks"]["items"][0]["id"]
    ftr = sp.audio_features(idr)
    ftr2 = pd.DataFrame(ftr)
    ftr2["Artist"] = artistname
    ftr2["Track"] = search_str
    ft2 = ft2.append(ftr2)
# Out:
# Casual,I Didn't Mean To
# 01TR6aAKrA2cI3Z0gnCOsu
# The Box Tops,Soul Deep
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# 4yPl1mK1oluIrCwI4HInPR
# Sonora Santanera,Amor De Cabaret
# 5JeyXbf7CrVQ8DqwFikN0P
# Adam Ant,Something Girls
# 0ygZMtr5JdKEk1Nn58HB0V
# Gob,Face the Ashes
# 4cdbM6efK43Cs2PDMtzdhv
# Jeff And Sheri Easter,The Moon And I (Ordinary Day Album Version)
# 7ERvcsBBYzSHqQQqlI9xAN
# Rated R,Keepin It Real (Skit)
# 0e4hF4Jxyh7cuwB2pMYhBh
# Tweeterfriendly Music,Drop of Rain
# 6dfppQDZQ4x3fCs6N89kV3
# Planet P Project,Pink World
# 0CVy6Avr53ZCYfHSDGVftj
# Clp,Insatiable (Instrumental Version)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-43e640b47a53> in <module>
#       6     print(artistname+ ","+ search_str )
#       7     result= sp.search(search_str+":"+artistname,type="track,artist")
# ----> 8     print(result["tracks"]["items"][0]["id"])
#       9     idr = result["tracks"]["items"][0]["id"]
#      10     ftr = sp.audio_features(idr)
#
# IndexError: list index out of range

# %%
ft2
# Out:
#                   Artist                                        Track  \
# 0                 casual                             I Didn't Mean To
# 0                 Casual                             I Didn't Mean To
# 0           The Box Tops                                    Soul Deep
# 0       Sonora Santanera                              Amor De Cabaret
# 0               Adam Ant                              Something Girls
# 0                    Gob                               Face the Ashes
# 0  Jeff And Sheri Easter  The Moon And I (Ordinary Day Album Version)
# 0                Rated R                        Keepin It Real (Skit)
# 0  Tweeterfriendly Music                                 Drop of Rain
# 0       Planet P Project                                   Pink World
#
#    acousticness                                       analysis_url  \
# 0      0.063000  https://api.spotify.com/v1/audio-analysis/01TR...
# 0      0.063000  https://api.spotify.com/v1/audio-analysis/01TR...
# 0      0.195000  https://api.spotify.com/v1/audio-analysis/4yPl...
# 0      0.689000  https://api.spotify.com/v1/audio-analysis/5Jey...
# 0      0.218000  https://api.spotify.com/v1/audio-analysis/0ygZ...
# 0      0.000356  https://api.spotify.com/v1/audio-analysis/4cdb...
# 0      0.706000  https://api.spotify.com/v1/audio-analysis/7ERv...
# 0      0.799000  https://api.spotify.com/v1/audio-analysis/0e4h...
# 0      0.553000  https://api.spotify.com/v1/audio-analysis/6dfp...
# 0      0.133000  https://api.spotify.com/v1/audio-analysis/0CVy...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.751       218933   0.549  01TR6aAKrA2cI3Z0gnCOsu
# 0         0.751       218933   0.549  01TR6aAKrA2cI3Z0gnCOsu
# 0         0.749       147760   0.530  4yPl1mK1oluIrCwI4HInPR
# 0         0.699       183027   0.519  5JeyXbf7CrVQ8DqwFikN0P
# 0         0.606       232107   0.937  0ygZMtr5JdKEk1Nn58HB0V
# 0         0.525       209600   0.918  4cdbM6efK43Cs2PDMtzdhv
# 0         0.456       267640   0.472  7ERvcsBBYzSHqQQqlI9xAN
# 0         0.683       112947   0.173  0e4hF4Jxyh7cuwB2pMYhBh
# 0         0.498       189560   0.300  6dfppQDZQ4x3fCs6N89kV3
# 0         0.332       280907   0.834  0CVy6Avr53ZCYfHSDGVftj
#
#    instrumentalness  key  ...  loudness  mode  popularity  speechiness  \
# 0          0.000025    6  ...   -10.508     0        21.0       0.4290
# 0          0.000025    6  ...   -10.508     0         NaN       0.4290
# 0          0.000035    9  ...   -12.940     1         NaN       0.0326
# 0          0.000471    8  ...    -6.422     1         NaN       0.0290
# 0          0.005870    0  ...    -3.808     1         NaN       0.0443
# 0          0.566000    2  ...    -4.512     1         NaN       0.0543
# 0          0.000005    5  ...    -8.328     1         NaN       0.0325
# 0          0.000000    1  ...   -16.056     1         NaN       0.8950
# 0          0.000116    7  ...   -10.716     1         NaN       0.0352
# 0          0.000038    4  ...    -5.312     0         NaN       0.0467
#
#      tempo  time_signature                                         track_href  \
# 0   92.224               4  https://api.spotify.com/v1/tracks/01TR6aAKrA2c...
# 0   92.224               4  https://api.spotify.com/v1/tracks/01TR6aAKrA2c...
# 0  121.395               4  https://api.spotify.com/v1/tracks/4yPl1mK1oluI...
# 0  102.463               4  https://api.spotify.com/v1/tracks/5JeyXbf7CrVQ...
# 0  120.135               4  https://api.spotify.com/v1/tracks/0ygZMtr5JdKE...
# 0  129.727               4  https://api.spotify.com/v1/tracks/4cdbM6efK43C...
# 0  147.565               4  https://api.spotify.com/v1/tracks/7ERvcsBBYzSH...
# 0   83.834               4  https://api.spotify.com/v1/tracks/0e4hF4Jxyh7c...
# 0  100.315               3  https://api.spotify.com/v1/tracks/6dfppQDZQ4x3...
# 0  104.953               4  https://api.spotify.com/v1/tracks/0CVy6Avr53ZC...
#
#              type                                   uri valence
# 0  audio_features  spotify:track:01TR6aAKrA2cI3Z0gnCOsu   0.553
# 0  audio_features  spotify:track:01TR6aAKrA2cI3Z0gnCOsu   0.553
# 0  audio_features  spotify:track:4yPl1mK1oluIrCwI4HInPR   0.966
# 0  audio_features  spotify:track:5JeyXbf7CrVQ8DqwFikN0P   0.676
# 0  audio_features  spotify:track:0ygZMtr5JdKEk1Nn58HB0V   0.853
# 0  audio_features  spotify:track:4cdbM6efK43Cs2PDMtzdhv   0.655
# 0  audio_features  spotify:track:7ERvcsBBYzSHqQQqlI9xAN   0.286
# 0  audio_features  spotify:track:0e4hF4Jxyh7cuwB2pMYhBh   0.696
# 0  audio_features  spotify:track:6dfppQDZQ4x3fCs6N89kV3   0.185
# 0  audio_features  spotify:track:0CVy6Avr53ZCYfHSDGVftj   0.327
#
# [10 rows x 21 columns]

# %%
# iterate over the dataframe row by row
for i,j in dft.iterrows():
   # For each row update the 'Bonus' value to it's double  
    artistname= row['ArtistName']
    search_str =  row['SongTitle']
    print(artistname+ ","+ search_str )
    result= sp.search(search_str+":"+artistname,type="track,artist")
    if len(result["tracks"]) == 0:
        print("empty")
    else:
        print(result["tracks"]["items"][0]["id"])
        ftr = sp.audio_features(idr)
        ftr2 = pd.DataFrame(ftr)
        ftr2["Artist"] = artistname
        ftr2["Track"] = search_str
        dft = dft.append(ftr2)
# Out:
# Clp,Insatiable (Instrumental Version)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-71453d3136e4> in <module>
#       9         print("empty")
#      10     else:
# ---> 11         print(result["tracks"]["items"][0]["id"])
#      12         ftr = sp.audio_features(idr)
#      13         ftr2 = pd.DataFrame(ftr)
#
# IndexError: list index out of range
