# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# import sys
# sys.path.append('C:\\Users\\Suhaib Kiani\\Desktop')
import exp

# %%
file = "test_dataset.csv"
tds1 = pd.read_csv(file)
#tds1.head()
tds1.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'popularity',
#        'Artist', 'Track'],
#       dtype='object')

# %%
tds1 = tds1[['Artist', 'Track','popularity','acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'time_signature', 'valence']]

# %%
tds1.head()
# Out:
#              Artist             Track  popularity  acousticness  danceability  \
# 0            casual  I Didn't Mean To          21         0.063         0.751
# 1            Casual  I Didn't Mean To          21         0.063         0.751
# 2      The Box Tops         Soul Deep          37         0.195         0.749
# 3  Sonora Santanera   Amor De Cabaret          50         0.689         0.699
# 4          Adam Ant   Something Girls          19         0.218         0.606
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       218933   0.549          0.000025    6    0.1060   -10.508     0
# 1       218933   0.549          0.000025    6    0.1060   -10.508     0
# 2       147760   0.530          0.000035    9    0.0748   -12.940     1
# 3       183027   0.519          0.000471    8    0.9350    -6.422     1
# 4       232107   0.937          0.005870    0    0.1630    -3.808     1
#
#    speechiness    tempo  time_signature  valence
# ...

# %%
tds1.describe()
# Out:
#        popularity  acousticness  danceability    duration_ms     energy  \
# count   44.000000     44.000000     44.000000      44.000000  44.000000
# mean    12.340909      0.323777      0.579591  242392.045455   0.615886
# std     14.890208      0.304141      0.160869  105828.233789   0.240367
# min      0.000000      0.000006      0.197000   95853.000000   0.173000
# 25%      1.000000      0.032875      0.492750  185586.750000   0.463500
# 50%      7.000000      0.241500      0.582000  218067.000000   0.570500
# 75%     20.250000      0.610500      0.716250  270173.250000   0.851500
# max     50.000000      0.814000      0.839000  599240.000000   0.999000
#
#        instrumentalness        key   liveness   loudness       mode  \
# count         44.000000  44.000000  44.000000  44.000000  44.000000
# mean           0.139414   4.931818   0.227157  -9.155364   0.795455
# std            0.266659   3.187167   0.223709   3.949966   0.408032
# ...

# %%
tds1_copy= tds1[['danceability','energy']].copy()
tds1_copy.head()
# Out:
#    danceability  energy
# 0         0.751   0.549
# 1         0.751   0.549
# 2         0.749   0.530
# 3         0.699   0.519
# 4         0.606   0.937

# %%
tds1_copy.describe()
# Out:
#        danceability     energy
# count     44.000000  44.000000
# mean       0.579591   0.615886
# std        0.160869   0.240367
# min        0.197000   0.173000
# 25%        0.492750   0.463500
# 50%        0.582000   0.570500
# 75%        0.716250   0.851500
# max        0.839000   0.999000

# %% [markdown]
# # Data Analysis & Visualization

# %% [markdown]
# ## Scatter Plots

# %%
exp.plot_bivariate(tds1, 'popularity', 'acousticness', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'duration_ms', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'energy', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'instrumentalness', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'key', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'liveness', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'loudness', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'mode', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'speechiness', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'tempo', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'time_signature', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
exp.plot_bivariate(tds1, 'popularity', 'valence', hue='key', alpha=1.0)
plt.legend(bbox_to_anchor=(1.0, 1), loc='upper left', borderaxespad=0.)
#plt.savefig('scatter1.png')

# %%
# Comparing two features

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["danceability"]<0.57)&
                                    (tds1["energy"] < 0.61),:]
exp.plot_bivariate(tds1_loc , 'danceability', 'energy', hue='key', alpha=1.0)

# %%
# Comparing two features

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["danceability"]>0.57)&
                                    (tds1["energy"] > 0.61),:]
exp.plot_bivariate(tds1_loc , 'danceability', 'energy', hue='key', alpha=1.0)

# %%
# Comparing two features   

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["acousticness"]<0.32)&
                                    (tds1["loudness"] < -9.15),:]
exp.plot_bivariate(tds1_loc , 'acousticness', 'loudness', hue='key', alpha=1.0)

# %%
# Comparing two features

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["acousticness"]>0.32)&
                                    (tds1["loudness"] > -9.15),:]
exp.plot_bivariate(tds1_loc , 'acousticness', 'loudness', hue='key', alpha=1.0)

# %%
# Comparing two features   

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["duration_ms"]<242392.04)&
                                    (tds1["liveness"] < 0.22),:]
exp.plot_bivariate(tds1_loc , 'duration_ms', 'liveness', hue='key', alpha=1.0)

# %%
# Comparing two features

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["duration_ms"]>242392.04)&
                                    (tds1["liveness"] > 0.22),:]
exp.plot_bivariate(tds1_loc , 'duration_ms', 'liveness', hue='key', alpha=1.0)

# %%
# Comparing two features    

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["instrumentalness"]<0.14)&
                                    (tds1["valence"] < 0.57),:]
exp.plot_bivariate(tds1_loc , 'instrumentalness', 'valence', hue='key', alpha=1.0)

# %%
# Comparing two features

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["instrumentalness"]>0.14)&
                                    (tds1["valence"] > 0.57),:]
exp.plot_bivariate(tds1_loc , 'instrumentalness', 'valence', hue='key', alpha=1.0)

# %%
# Comparing two features  

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["mode"]>0.79)&
                                    (tds1["tempo"] > 119.67),:]
exp.plot_bivariate(tds1_loc , 'mode', 'tempo', hue='key', alpha=1.0)

# %%
# Comparing two features  

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["mode"]<0.79)&
                                    (tds1["tempo"] < 119.67),:]
exp.plot_bivariate(tds1_loc , 'mode', 'tempo', hue='key', alpha=1.0)

# %%
# Comparing two features 

# less than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["speechiness"]<0.10)&
                                    (tds1["time_signature"] < 3.97),:]
exp.plot_bivariate(tds1_loc , 'speechiness', 'time_signature', hue='key', alpha=1.0)

# %%
# Comparing two features

# more than the mean value of those two columns
tds1_loc = tds1.loc[(tds1["speechiness"]>0.10)&
                                    (tds1["time_signature"] > 3.97),:]
exp.plot_bivariate(tds1_loc , 'speechiness', 'time_signature', hue='key', alpha=1.0)

# %% [markdown]
# ## The Big Picture

# %%
#Please change the code to create graphic(s) similar to Brooklyn reference..
sns.set()
cols = ['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'time_signature', 'valence']
sns.pairplot(tds1[cols], size = 2.5)
plt.show();
#plt.savefig('Big_picture.png')
# Out:
# C:\Users\Irisi\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Box Plots

# %%
#Please change the code to create graphic(s) similar to Brooklyn reference..

var = tds1["popularity"]
SP = tds1["danceability"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %%
var = tds1["popularity"]
SP = tds1["acousticness"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %%
var = tds1["popularity"]
SP = tds1["duration_ms"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=600000);

# %%
var = tds1["popularity"]
SP = tds1["energy"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %%
var = tds1["popularity"]
SP = tds1["instrumentalness"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %%
var = tds1["popularity"]
SP = tds1["key"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=12);

# %%
var = tds1["popularity"]
SP = tds1["liveness"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %%
var = tds1["popularity"]
SP = tds1["loudness"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=-20, ymax=0);

# %%
var = tds1["popularity"]
SP = tds1["mode"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=-0.5, ymax=1.5);

# %%
var = tds1["popularity"]
SP = tds1["speechiness"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=0.5);

# %%
var = tds1["popularity"]
SP = tds1["tempo"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=180);

# %%
var = tds1["popularity"]
SP = tds1["valence"]
data = pd.concat([SP, var], axis=1)
f, ax = plt.subplots(figsize=(20, 6))
fig = sns.boxplot(x=var, y=SP, data=data)
fig.axis(ymin=0, ymax=1);

# %% [markdown]
# ## Heat Maps

# %%
#correlation matrix
corrmat = tds1.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
#plt.savefig('Heat1.png')

# %%
exp.plot_correlations(tds1, 'popularity', limit=10, annot=True)
# Out:
# popularity          1.000000
# acousticness       -0.314653
# loudness            0.256228
# energy              0.254062
# instrumentalness   -0.222116
# danceability        0.220591
# valence             0.216263
# key                 0.204845
# duration_ms        -0.151482
# time_signature      0.127851
# Name: popularity, dtype: float64

# %%
print("Find most important features relative to target")
corr = tds1.corr()
corr.sort_values(["popularity"], ascending = False, inplace = True)
print(corr.popularity)
# Out:
# Find most important features relative to target
# popularity          1.000000
# loudness            0.256228
# energy              0.254062
# danceability        0.220591
# valence             0.216263
# key                 0.204845
# time_signature      0.127851
# liveness            0.100013
# tempo               0.064500
# speechiness         0.012063
# mode                0.011744
# duration_ms        -0.151482
# instrumentalness   -0.222116
# acousticness       -0.314653
# Name: popularity, dtype: float64
