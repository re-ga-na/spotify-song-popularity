# %%
import pandas as pd
import requests
import sys
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
features = pd.read_csv("features_15k.csv")
features.shape
# Out:
# (12064, 17)

# %%
#del df['ID1']
features = features.head(1)
features
# Out:
#           Artist                    Track  acousticness  danceability  \
# 0  Lionel Richie  Tonight Will Be Alright        0.0591         0.646
#
#    duration_ms  energy  followers  instrumentalness  key  liveness  loudness  \
# 0       307413    0.84    1627956            0.0141    8    0.0516    -8.213
#
#    mode  popularity  speechiness    tempo  time_signature  valence
# 0     1          38       0.0283  125.187               4    0.716

# %%
#setting up link to spotify api w spotipy
client_id = "5028c957611248149d8c04007258f254"
client_secret = "aa56a507cb944f488f8835062a94115c"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # Add Songs from Spotify 21k

# %%
df = pd.read_csv("spotify_dataset_21k.csv")
df.shape
# Out:
# (20829, 7)

# %%
df_batch1 = df.iloc[20001:25000]
df_batch1.shape
# Out:
# (828, 7)

# %%
# iterate over the dataframe row by row
for index_label, row in df_batch1.iterrows():
   # For each row update the 'Bonus' value to it's double  

    try: 
        artistname= row['Artist']
        search_str =  row['Track']
        print(artistname+ ","+ search_str )
        result= sp.search(search_str+":"+artistname,type="track,artist")
        print(result["tracks"]["items"][0]["id"])
        
        track_id = result["tracks"]["items"][0]["id"]
        artist_id = result['tracks']['items'][0]["album"]['artists'][0]['id']
        
        features_i = sp.audio_features(track_id)
        features_i = pd.DataFrame(features_i)
        
        #features["genres"] = sp.artist(artist_id)['genres']
        features_i["followers"] = sp.artist(artist_id)['followers']['total']
        features_i["tempo"] = sp.audio_analysis(track_id)['track']['tempo']
        features_i["popularity"] = sp.track(track_id)["popularity"]
        features_i["Artist"] = artistname
        features_i["Track"] = search_str
        features = features.append(features_i)
        
    except: 
        print ('data not found')
# Out:
# The Alan Parsons Project,The Turn of a Friendly Card
# 2gQsUHVFY4tpXc3AFU2mcS
# Fischer-Z,So Long
# 3XAiXl3dKpG7b0qcrCtBD4
# Dire Straits,Tunnel of Love (Intro: The Carousel Waltz)
# 06ku5BBS2HufqSDVkcSR15
# ABBA,Happy New Year
# 7nvmxaLf5hq9ZDTIMME27m
# David Bowie,Ashes to Ashes - 2017 Remaster
# 37CRPk0L5ZpfPeePEPwE0t
# Rob De Nijs,Foto Van Vroeger
# 3h9k4hZVdPWV9E3xQwZuKI
# Bob Marley & The Wailers,Could You Be Loved
# 5O4erNlJ74PIF6kGol1ZrC
# Dolly Parton,9 to 5
# 4w3tQBXhn5345eUXDGBWZG
# The Blues Brothers,Everybody Needs Somebody to Love
# 1CtKHwDqsH3ctcCCI18N0g
# ABBA,Super Trouper
# 2nMghZvtLx6DDgTEHEsb4w
# Queen,Save Me - Remastered 2011
# 2mGEqJahn3CSyCG1BTEqMs
# REO Speedwagon,Keep on Loving You
# 4rcHWl68ai6KvpXlc8vbnE
# Barbra Streisand,Woman in Love
# 1pTGc8pwyo6xtgXBKCBcFn
# Rush,The Spirit Of Radio
# 4e9hUiLsN4mx61ARosFi7p
# Madness,Baggy Trousers
# 3Sbnhrpec0ULbeWBsA6GS6
# Bruce Springsteen,Hungry Heart
# 1KsI8NEeAna8ZIdojI3FiT
# ...

# %%
features.shape
# Out:
# (5703, 22)

# %%
features = features.drop(columns=['analysis_url', 'id', 'track_href', 'type', 'uri'])
features
# Out:
#                       Artist                    Track  acousticness  \
# 0              Lionel Richie  Tonight Will Be Alright       0.05910
# 0                     Lucero      For the Lonely Ones       0.06810
# 0                  Elle King     Little Bit Of Lovin'       0.59300
# 0                       Mona        Some Kind Of Rage       0.07100
# 0       Manchester Orchestra                 The Gold       0.00119
# ..                       ...                      ...           ...
# 0              Elvis Presley         Heartbreak Hotel       0.84000
# 0              Elvis Presley                Hound Dog       0.73300
# 0                Chuck Berry          Johnny B. Goode       0.74100
# 0   The Dave Brubeck Quartet                Take Five       0.53900
# 0                Fats Domino           Blueberry Hill       0.84900
#
#     danceability  duration_ms  energy  followers  instrumentalness  key  \
# 0          0.646       307413   0.840    1627956          0.014100    8
# ...

# %%
featues_20_25k_iris = features
featues_20_25k_iris.to_csv (r'C:\Users\Irisi\spotify-song-popularity\Resources\featues_20_25k_iris.csv', index = False, header=True)

# %% [markdown]
# ## Dataset Batches Join/Append

# %%
import os
import pandas as pd
import numpy as np

# %%
resource_path = './Resources'
spotify_files = [os.path.join(resource_path, f) for f in os.listdir(resource_path) if os.path.isfile(os.path.join(resource_path, f)) 
              and f.find('.csv') != -1]
# list comprehention
for file in spotify_files:
    print(file)
# Out:
# ./Resources\featues_10k_iris.csv
# ./Resources\featues_15_20_iris.csv

# %%
all_files = []
for f in spotify_files:
    df = pd.read_csv(f)
    all_files.append(df)
spotify_data_iris = pd.concat(all_files)
spotify_data_iris.head()
# Out:
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#     0            Artist                    Track  acousticness  danceability  \
# 0 NaN     Lionel Richie  Tonight Will Be Alright       0.05910         0.646
# 1 NaN  Guided By Voices           Game of Pricks       0.24800         0.372
# 2 NaN             Wilco        A Shot In The Arm       0.04860         0.556
# 3 NaN        White Town               Your Woman       0.03300         0.815
# 4 NaN               Air                 Sexy Boy       0.00111         0.435
#
#    duration_ms  energy  followers  instrumentalness  key  liveness  loudness  \
# 0     307413.0   0.840    1627956          0.014100  8.0    0.0516    -8.213
# ...

# %%
spotify_data_iris.to_csv('spotify_data_iris.csv', sep = ',')

# %%
spotify_data_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15338 entries, 0 to 5702
# Data columns (total 18 columns):
# 0                   0 non-null float64
# Artist              15338 non-null object
# Track               15338 non-null object
# acousticness        15334 non-null float64
# danceability        15334 non-null float64
# duration_ms         15334 non-null float64
# energy              15334 non-null float64
# followers           15338 non-null int64
# instrumentalness    15334 non-null float64
# key                 15334 non-null float64
# liveness            15334 non-null float64
# loudness            15334 non-null float64
# mode                15334 non-null float64
# popularity          15338 non-null int64
# speechiness         15334 non-null float64
# tempo               15338 non-null float64
# time_signature      15334 non-null float64
# valence             15334 non-null float64
# dtypes: float64(14), int64(2), object(2)
# memory usage: 2.2+ MB

# %%
# drop duplicates
# spotify_data_iris.drop_duplicates(subset ="Track", keep = False, inplace = True)

# %%
# dropping duplicate values 
spotify_data_iris.drop_duplicates(keep=False,inplace=True) 
spotify_data_iris.count()
# Out:
# 0                       0
# Artist              11388
# Track               11388
# acousticness        11386
# danceability        11386
# duration_ms         11386
# energy              11386
# followers           11388
# instrumentalness    11386
# key                 11386
# liveness            11386
# loudness            11386
# mode                11386
# popularity          11388
# speechiness         11386
# tempo               11388
# time_signature      11386
# valence             11386
# dtype: int64

# %%
spotify_data_iris['acousticness'].replace(r'\s+', np.nan, regex=True)
# Out:
# 1       0.24800
# 2       0.04860
# 3       0.03300
# 4       0.00111
# 6       0.14700
#          ...
# 5698    0.84000
# 5699    0.73300
# 5700    0.74100
# 5701    0.53900
# 5702    0.84900
# Name: acousticness, Length: 11388, dtype: float64

# %%
# spotify_data_iris.dropna(how='all')

# %%
spotify_data_iris.count()
# Out:
# 0                       0
# Artist              11388
# Track               11388
# acousticness        11386
# danceability        11386
# duration_ms         11386
# energy              11386
# followers           11388
# instrumentalness    11386
# key                 11386
# liveness            11386
# loudness            11386
# mode                11386
# popularity          11388
# speechiness         11386
# tempo               11388
# time_signature      11386
# valence             11386
# dtype: int64

# %%
# replacing cells with no values with NA 
# spotify_data_iris_fill_na = spotify_data_iris.replace(r'', np.nan, regex=True)
# spotify_data_iris_fill_na.count()

# %%
# spotify_data_iris.count()

# %%
# drop NA
# spotify_data_iris.dropna()

# %%
# spotify_data_iris.count()
